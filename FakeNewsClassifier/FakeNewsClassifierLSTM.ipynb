# %% [markdown]
# # Fake News Classifier using LSTM

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
df.shape
# Out:
# (20800, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      20800 non-null  int64
#  1   title   20242 non-null  object
#  2   author  18843 non-null  object
#  3   text    20761 non-null  object
#  4   label   20800 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 812.6+ KB

# %%
(df.isnull().sum()/len(df))*100
# Out:
# id        0.000000
# title     2.682692
# author    9.408654
# text      0.187500
# label     0.000000
# dtype: float64

# %%
df = df.dropna()

# %%
(df.isnull().sum()/len(df))*100
# Out:
# id        0.0
# title     0.0
# author    0.0
# text      0.0
# label     0.0
# dtype: float64

# %%
messages = df.copy()

# %%
messages.reset_index(inplace=True)

# %%
import re
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
stemmer = PorterStemmer()

# %%
title_corpus = []
for i in range(len(messages['title'])):
    review = re.sub('\W',' ',messages['title'][i])
    review = review.lower()
    review = review.split()
    review = [stemmer.stem(word) for word in review if word not in stopwords.words('english')]
    review = ' '.join(review)
    title_corpus.append(review)

# %%
title_corpus[3]
# Out:
# '15 civilian kill singl us airstrik identifi'

# %%
y = messages.pop('label')
X = messages

# %%
X.shape
# Out:
# (18285, 5)

# %%
y.shape
# Out:
# (18285,)

# %%
X.drop(['index','id','author','text'],axis=1,inplace=True)

# %%
X.head()
# Out:
#                                                title
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2                  Why the Truth Might Get You Fired
# 3  15 Civilians Killed In Single US Airstrike Hav...
# 4  Iranian woman jailed for fictional unpublished...

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.6.0'

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import Dropout

# %%
voc_size = 5000

# %% [markdown]
# ## One Hot Representation

# %%
one_hot_corpus = [one_hot(sent,voc_size) for sent in title_corpus]
print(one_hot_corpus)
# Out:
# [[3685, 1793, 3235, 3300, 3727, 775, 1587, 4659, 4369, 4024], [3423, 4571, 4766, 3870, 3690, 409, 4030], [738, 3906, 1521, 1923], [4501, 3230, 2478, 4050, 101, 1707, 1481], [3949, 3690, 1582, 1177, 3075, 4466, 3690, 1281, 4889, 378], [2867, 531, 2684, 2340, 2195, 2704, 631, 3466, 675, 2952, 1243, 2100, 1121, 585, 4030], [2480, 2776, 3399, 3027, 1218, 820, 80, 685, 2953, 4346, 4236], [4168, 3039, 2175, 4057, 1096, 2668, 2704, 2809, 2953, 4346, 4236], [3795, 977, 3011, 3030, 4024, 2648, 655, 3426, 2704, 683], [1886, 2289, 4119, 3689, 3309, 2758, 4467, 1463], [1264, 1982, 3886, 1724, 3748, 2042, 3243, 4736, 1434, 4174, 1687], [101, 3256, 3727, 2648, 2704, 1096], [1286, 868, 635, 1520, 3084, 4376, 4505, 275, 1462], [2869, 4706, 301, 3713, 2240, 3397, 2915, 2953, 4346, 4236], [4944, 65, 2486, 4270, 3671, 2953, 4346, 4236], [4716, 318, 3339, 2455, 1654, 3286, 4482, 2957, 438, 1797, 4642, 2302], [2486, 1584, 4571], [3993, 2432, 1700, 2588, 2704, 4999, 3591, 4030], [2187, 795, 4766, 1123, 1609, 1410, 3792, 1509, 4466], [3059, 4863, 2704, 2113, 4303, 4030], [2927, 617, 4955, 632, 903, 589, 3792, 4409, 894, 2872, 2953, 4346, 4236], [4839, 1999, 2412, 619, 4260, 4058, 1907], [1121, 2161, 3844, 3788, 414, 1997, 350, 1679, 2714, 363, 2127, 4030], [2897, 4571, 3221, 2576, 4237, 2824, 4501, 3859, 4096], [3988, 1306, 1732, 2250, 4999, 2063, 1123, 2406, 3463, 2953, 4346, 4236], [4571, 4766, 2451, 3486, 2953, 4346, 4236], [3993, 2432, 1700, 3026, 2111, 344, 2250, 4030], [4775, 2036
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics='accuracy')
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 20, 40)            200000
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               56400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 256,501
# Trainable params: 256,501
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import numpy as np

# %%
X_final = np.array(padded_docs)
y_final = np.array(y)

# %%
X_final.shape,y_final.shape
# Out:
# ((18285, 20), (18285,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size=0.33, random_state=42)

# %% [markdown]
# ### Model Training

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=20,batch_size=64)
# Out:
# Epoch 1/20
# 192/192 [==============================] - 4s 11ms/step - loss: 0.3385 - accuracy: 0.8368 - val_loss: 0.1943 - val_accuracy: 0.9137
# Epoch 2/20
# 192/192 [==============================] - 2s 9ms/step - loss: 0.1384 - accuracy: 0.9455 - val_loss: 0.2204 - val_accuracy: 0.9198
# Epoch 3/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0896 - accuracy: 0.9682 - val_loss: 0.2277 - val_accuracy: 0.9130
# Epoch 4/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0586 - accuracy: 0.9800 - val_loss: 0.2802 - val_accuracy: 0.9153
# Epoch 5/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0329 - accuracy: 0.9892 - val_loss: 0.3237 - val_accuracy: 0.9112
# Epoch 6/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0189 - accuracy: 0.9945 - val_loss: 0.3546 - val_accuracy: 0.9062
# Epoch 7/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.4095 - val_accuracy: 0.9099
# Epoch 8/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.5500 - val_accuracy: 0.9105
# Epoch 9/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0069 - accuracy: 0.9984 - val_loss: 0.5476 - val_accuracy: 0.9155
# Epoch 10/20
# 192/192 [==============================] - 2s 11ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.5761 - val_accuracy: 0.9084
# Epoch 11/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.5141 - val_accuracy: 0.9099
# Epoch 12/20
# 192/192 [==============================] - 2s 11ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.5805 - val_accuracy: 0.9042
# Epoch 13/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.7277 - val_accuracy: 0.9074
# Epoch 14/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.6304 - val_accuracy: 0.9031
# Epoch 15/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.7314 - val_accuracy: 0.9077
# Epoch 16/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.8023 - val_accuracy: 0.9123
# Epoch 17/20
# 192/192 [==============================] - 2s 11ms/step - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.4960 - val_accuracy: 0.9059
# Epoch 18/20
# 192/192 [==============================] - 2s 11ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.6934 - val_accuracy: 0.9047
# Epoch 19/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.7340 - val_accuracy: 0.9097
# Epoch 20/20
# 192/192 [==============================] - 2s 10ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.6862 - val_accuracy: 0.9069

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
y_pred
# Out:
# array([[1],
#        [0],
#        [0],
#        ...,
#        [0],
#        [1],
#        [1]])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[3118,  301],
#        [ 261, 2355]], dtype=int64)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9068765534382767

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92      3419
#            1       0.89      0.90      0.89      2616
#
#     accuracy                           0.91      6035
#    macro avg       0.90      0.91      0.91      6035
# weighted avg       0.91      0.91      0.91      6035
